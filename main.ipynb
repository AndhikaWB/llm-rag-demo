# %% [markdown]
# ## Initial setup

# %%
import dotenv

from llmware.configs import LLMWareConfig, ChromaDBConfig
from llmware.models import ModelCatalog
from llmware.library import Library
from llmware.retrieval import Query
from llmware.prompts import Prompt
from llmware.embeddings import EmbeddingChromaDB

# %%
# Load environment variables
dotenv.load_dotenv()

# Set default home directory (may cause some issues)
# https://github.com/llmware-ai/llmware/issues/919
# LLMWareConfig().set_home('data')

# Set log verbosity
LLMWareConfig().set_config('debug_mode', 2)

# %%
# Query (context) for searching knowledge on our documents
# The most relevant results (similarity) will be passed to RAG prompt
# The context usually should be a keyword/topic, but question may also work
input_query = 'fufufafa'
# The actual prompt question/input
input_prompt = 'Is Gibran behind fufufafa?'

# %% [markdown]
# ## Prepare library
#
# And add documents to that library

# %%
# # Download data
# r = requests.get(url)
# with open('data/files.zip', 'wb') as f:
#     f.write(r.content)

# # Extract data
# with zipfile.ZipFile('data/files.zip', 'r') as f:
#     f.extractall('data/files')

# %%
# Set database engine to save library data
# If using SQLite, db will be saved to "accounts" folder
LLMWareConfig().set_active_db('sqlite')

try:
    # Delete library if already exist to ensure fresh start
    Library().delete_library(
        library_name = 'fufufafa',
        account_name = 'dhika',
        confirm_delete = True
    )
except: pass

lib = Library().create_new_library(
    library_name = 'fufufafa',
    account_name = 'dhika'
)

# Folder containing files to add to library
lib_folder = 'data/files'

# There is also "add_website" function
# But can cause rate limit and IP blacklist
lib.add_files(
    # Files will be copied to "uploads" folder once added to library
    input_folder_path = lib_folder,
    # Min characters per embedding block
    # Usually separated per X sentences
    chunk_size = 400,
    # Max characters per embedding block
    max_chunk_size = 600
)
# Out:
# INFO: update:  Duplicate files (skipped): 0
# INFO: update:  Total uploaded: 10
# INFO: Parser - parse_text file - processing - 1.txt
# INFO: Parser - parse_text file - processing - 10.txt
# INFO: Parser - parse_text file - processing - 2.txt
# INFO: Parser - parse_text file - processing - 3.txt
# INFO: Parser - parse_text file - processing - 4.txt
# INFO: Parser - parse_text file - processing - 5.txt
# INFO: Parser - parse_text file - processing - 6.txt
# INFO: Parser - parse_text file - processing - 7.txt
# INFO: Parser - parse_text file - processing - 8.txt
# INFO: Parser - parse_text file - processing - 9.txt
# {'docs_added': 10,
#  'blocks_added': 41,
#  'images_added': 0,
#  'pages_added': 10,
#  'tables_added': 0,
#  'rejected_files': []}

# %% [markdown]
# ## Prepare embedding model
#
# And also the database engine to store the vector

# %%
# ModelCatalog().list_embedding_models()

# %%
# Database engine to save vector embedding
# If using ChromaDB, db will be saved to "accounts" folder
LLMWareConfig().set_vector_db('chromadb')

# Model will be downloaded from Hugging Face if not exist yet
# https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2
lib.install_new_embedding(
    embedding_model_name = 'mini-lm-sbert',
    batch_size = 100
)

print('Vector database path:', ChromaDBConfig().get_config("persistent_path"))
# Get embedding status and our documents
lib.get_library_card()
# Out:
# WARNING: Insert of existing embedding ID: 1-1
# WARNING: Insert of existing embedding ID: 1-2
# WARNING: Insert of existing embedding ID: 1-3
# WARNING: Insert of existing embedding ID: 1-4
# WARNING: Insert of existing embedding ID: 2-5
# WARNING: Insert of existing embedding ID: 2-6
# WARNING: Insert of existing embedding ID: 2-7
# WARNING: Insert of existing embedding ID: 2-8
# WARNING: Insert of existing embedding ID: 2-9
# WARNING: Insert of existing embedding ID: 3-10
# WARNING: Insert of existing embedding ID: 3-11
# WARNING: Insert of existing embedding ID: 3-12
# WARNING: Insert of existing embedding ID: 4-13
# WARNING: Insert of existing embedding ID: 4-14
# WARNING: Insert of existing embedding ID: 4-15
# WARNING: Insert of existing embedding ID: 4-16
# WARNING: Insert of existing embedding ID: 4-17
# WARNING: Insert of existing embedding ID: 5-18
# WARNING: Insert of existing embedding ID: 5-19
# WARNING: Insert of existing embedding ID: 5-20
# WARNING: Insert of existing embedding ID: 6-21
# WARNING: Insert of existing embedding ID: 6-22
# WARNING: Insert of existing embedding ID: 6-23
# WARNING: Insert of existing embedding ID: 6-24
# WARNING: Insert of existing embedding ID: 6-25
# WARNING: Insert of existing embedding ID: 7-26
# WARNING: Insert of existing embedding ID: 7-27
# WARNING: Insert of existing embedding ID: 7-28
# WARNING: Insert of existing embedding ID: 7-29
# WARNING: Insert of existing embedding ID: 8-30
# WARNING: Insert of existing embedding ID: 8-31
# WARNING: Insert of existing embedding ID: 8-32
# WARNING: Insert of existing embedding ID: 8-33
# WARNING: Insert of existing embedding ID: 8-34
# WARNING: Insert of existing embedding ID: 9-35
# WARNING: Insert of existing embedding ID: 9-36
# WARNING: Insert of existing embedding ID: 9-37
# WARNING: Insert of existing embedding ID: 9-38
# WARNING: Insert of existing embedding ID: 10-39
# WARNING: Insert of existing embedding ID: 10-40
# WARNING: Insert of existing embedding ID: 10-41
# WARNING: Add of existing embedding ID: 1-1
# WARNING: Add of existing embedding ID: 1-2
# WARNING: Add of existing embedding ID: 1-3
# WARNING: Add of existing embedding ID: 1-4
# WARNING: Add of existing embedding ID: 2-5
# WARNING: Add of existing embedding ID: 2-6
# WARNING: Add of existing embedding ID: 2-7
# WARNING: Add of existing embedding ID: 2-8
# WARNING: Add of existing embedding ID: 2-9
# WARNING: Add of existing embedding ID: 3-10
# WARNING: Add of existing embedding ID: 3-11
# WARNING: Add of existing embedding ID: 3-12
# WARNING: Add of existing embedding ID: 4-13
# WARNING: Add of existing embedding ID: 4-14
# WARNING: Add of existing embedding ID: 4-15
# WARNING: Add of existing embedding ID: 4-16
# WARNING: Add of existing embedding ID: 4-17
# WARNING: Add of existing embedding ID: 5-18
# WARNING: Add of existing embedding ID: 5-19
# WARNING: Add of existing embedding ID: 5-20
# WARNING: Add of existing embedding ID: 6-21
# WARNING: Add of existing embedding ID: 6-22
# WARNING: Add of existing embedding ID: 6-23
# WARNING: Add of existing embedding ID: 6-24
# WARNING: Add of existing embedding ID: 6-25
# WARNING: Add of existing embedding ID: 7-26
# WARNING: Add of existing embedding ID: 7-27
# WARNING: Add of existing embedding ID: 7-28
# WARNING: Add of existing embedding ID: 7-29
# WARNING: Add of existing embedding ID: 8-30
# WARNING: Add of existing embedding ID: 8-31
# WARNING: Add of existing embedding ID: 8-32
# WARNING: Add of existing embedding ID: 8-33
# WARNING: Add of existing embedding ID: 8-34
# WARNING: Add of existing embedding ID: 9-35
# WARNING: Add of existing embedding ID: 9-36
# WARNING: Add of existing embedding ID: 9-37
# WARNING: Add of existing embedding ID: 9-38
# WARNING: Add of existing embedding ID: 10-39
# WARNING: Add of existing embedding ID: 10-40
# WARNING: Add of existing embedding ID: 10-41
# INFO: update: embedding_handler - ChromaDB - Embeddings Created: 41 of 41
# INFO: update: EmbeddingHandler - ChromaDB - embedding_summary - {'embeddings_created': 41, 'embedded_blocks': 41, 'embedding_dims': 384, 'time_stamp': '2024-10-14_113127'}
# Vector database path: C:\Users\Dhika\llmware_data\accounts\
# {'_id': 1,
#  'library_name': 'fufufafa',
#  'embedding': [{'embedding_status': 'yes',
#    'embedding_model': 'mini-lm-sbert',
#    'embedding_db': 'chromadb',
#    'embedding_dims': 384,
#    'embedded_blocks': 41,
#    'time_stamp': '2024-10-14_113127'}],
#  'knowledge_graph': 'no',
#  'unique_doc_id': 10,
#  'documents': 10,
#  'blocks': 41,
#  'images': 0,
#  'pages': 10,
#  'tables': 0,
#  'account_name': 'dhika'}

# %%
# Query with our library as source
query = Query(lib)

# Query (search) something on library
# The knowledge will be passed to our prompt later
results = query.semantic_query(
    query = input_query,
    result_count = 20
)

for result in results:
    print('Text:', repr(result['text']))
    # Chunk size (sliced text from long document)
    # Each chunk will be saved to a unique block id
    # Chunk can also be passed to RAG prompt as knowledge later
    print('Text chunk/character size:', len(result['text']))
    # Block id on the database
    print('Block (chunk) id:',result['block_ID'])
    print('File source:',result['file_source'])
    print('Page number:', result['page_num'])
    print('Vector distance:', result['distance'], '\n')
# Out:
# Text: ' The comment history of this account, allegedly belonging to President Joko "Jokowi" Widodo\'s eldest son, dated back to before the 2014 election and extended to 2019 when the rivalry between Prabowo and Jokowi peaked.\n\nAn X user has even compiled a collection of Fufufafa\'s digital footprints. In this thread, the netizen claimed that Gibran allegedly used the usernames Raka Gnarly and Fufufafa on Kaskus.\n\nMany netizens shared several screenshots of uploads made by the Fufufafa account in the thread.'
# Text chunk/character size: 503
# Block (chunk) id: 1
# File source: 1.txt
# Page number: 1
# Vector distance: 0.2632857859134674
#
# Text: '\nA former government buzzer and two close associates of the Solo family—a reference to Jokowi’s family—who were familiar with the operation of the Fufufafa account, stated that the account was operated by a team working under the account’s owner. The team received content orders from the owner, who sometimes operated the account themselves.\n\nMeanwhile, on social media, netizens presented various pieces of evidence suggesting that the Fufufafa account belonged to Gibran. For example, the phone number registered by the account was suspected Gibran’s.'
# Text chunk/character size: 554
# Block (chunk) id: 15
# File source: 3.txt
# Page number: 1
# Vector distance: 0.30981960892677307
#
# Text: "Fufufafa Account Revelation Reportedly Causes Stir for Jokowi, Palace\n\nThe Indonesian social media landscape was recently abuzz with the revelation of a controversial Kaskus account named Fufufafa, which is widely believed to be linked to Gibran Rakabuming Raka, the eldest son of President Joko Jokowi Widodo. The account's existence has ignited a storm of speculation and controversy.\n\nFrom 2014 to 2019, the Fufufafa account posted numerous derogatory statements, often targeting Prabowo Subianto, a political rival of Jokowi during the 2014 and 2019 presidential elections.\n"
# Text chunk/character size: 578
# Block (chunk) id: 12
# File source: 3.txt
# Page number: 1
# Vector distance: 0.3308858275413513
#
# Text: '\nThe account also made homophobic comments about Prabowo’s only son Ragowo “Didit” Hediprasetyo Djojohadikusumo and salacious comments about female celebrities.\n\nAnother post from Fufufafa contained a racist remark toward Novela Nawipa, a cadre of Prabowo’s Gerindra Party from Papua.\n\nNetizens had been speculating that Gibran was behind Fufufafa because posts similar to those made on the forum also appeared on the vice president-elect’s other social media accounts.'
# Text chunk/character size: 469
# Block (chunk) id: 37
# File source: 8.txt
# Page number: 1
# Vector distance: 0.33779963850975037
#
# Text: "\nBesides, the ministry deleted thousands of Fufufafa's posts. Minister of Communication and Informatics Budi Arie Setiadi denied that his ministry was responsible for cleaning up the digital traces of the Fufufafa account. He insisted that the account did not belong to Gibran. However, Budi Arie did not deny that a meeting between Kominfo and BSSN took place.\n\n“We did not specifically discuss Fufufafa,” Budi Arie told Tempo on Friday, October 4, 2024. BSSN Chief Hinsa Siburian and his spokesperson, Ariandi Putra, did not respond to Tempo's messages or calls.\n"
# Text chunk/character size: 565
# Block (chunk) id: 14
# File source: 3.txt
# Page number: 1
# Vector distance: 0.3445359468460083
#
# Text: '\nA series of offensive comments posted by the user of an old account named Fufufafa on the internet forum Kaskus, a once-popular online venue for Indonesian youth, has been making the rounds on the internet over the past month, with some of its content involving slanders and mockery about Prabowo.\n\nThe comments were allegedly written between 2014 and 2019, when Prabowo ran twice against Jokowi in two presidential elections marked by sectarian and polarizing presidential campaigns.\n'
# Text chunk/character size: 486
# Block (chunk) id: 32
# File source: 7.txt
# Page number: 1
# Vector distance: 0.3461991250514984
#
# Text: " They became increasingly convinced that the account belonged to Gibran following a screenshot of Fufufafa’s comment admitting that he was Jokowi's first son.\n\nGibran's Response to Fufufafa Account \n\nWhen questioned by reporters about the accusation that he owned the Kaskus Fufufafa account, Gibran provided a brief response.\n\n“Ask the account owner,” he said when met after a visit to Mutihan Village, Laweyan District, Solo, Central Java, on Tuesday, September 10, 2024.\n\nMeanwhile, President's Special Staff Grace Natalie stated that the Fufufafa account does not necessarily belong to Gibran."
# Text chunk/character size: 597
# Block (chunk) id: 2
# File source: 1.txt
# Page number: 1
# Vector distance: 0.3500187397003174
#
# Text: '\nJokowi’s eldest son and vice president-elect Gibran Rakabuming Raka first recently entered the spotlight on social media for allegedly being the owner of “Fufufafa”, an account on Indonesian online forum Kaskus.\n\nThe account posted several times on the forum, including after the 2019 presidential election when it slandered Prabowo Subianto, who eventually became Gibran’s running mate in the February presidential election. In 2019, Prabowo ran for president against Gibran’s father, which resulted in Jokowi’s reelection.\n'
# Text chunk/character size: 526
# Block (chunk) id: 36
# File source: 8.txt
# Page number: 1
# Vector distance: 0.3726455271244049
#
# Text: 'Prabowo Indifferent to Gibran\'s Alleged Fufufafa Account, Says Dasco\n\nThe Daily Chair of the Gerindra Party, Sufmi Dasco Ahmad, has responded to the Kaskus social media account named Fufufafa, which has been accused of frequently attacking the party’s patron chief and President-elect Prabowo Subianto. The account\'s posts, allegedly belonging to President Joko "Jokowi" Widodo\'s eldest son, Gibran Rakabuming, have recently been widely discussed by the public.\n\nDasco clarified that Prabowo has not given much thought to the account\'s uploads.'
# Text chunk/character size: 544
# Block (chunk) id: 9
# File source: 2.txt
# Page number: 1
# Vector distance: 0.37407785654067993
#
# Text: "Gibran makes first public appearance since online furor over ‘Fufufafa’ account\n\nThe vice president-elect appears to have emerged from his weeks-long public absence by attending the TNI's 79th anniversary event on Oct. 5, the first time he has been seen out and about since the internet blew up over rumors that he was behind old posts slamming Prabowo on the Fufufafa social media account.\n"
# Text chunk/character size: 391
# Block (chunk) id: 4
# File source: 10.txt
# Page number: 1
# Vector distance: 0.3780134320259094
#
# Text: '\nSufmi’s statement came on the back of protracted speculations of frayed ties between Prabowo and Gibran, the son of outgoing President Joko “Jokowi” Widodo, particularly amid mounting accusations on social media that Gibran was the owner of an old account by the name of “Fufufafa” on the internet forum Kaskus, a once-popular online venue for Indonesian youth.\n\nThe account has in recent weeks been scrutinized by social media users due to several politically incorrect comments that took personal jabs at Prabowo and his family, dating all the way back to 2013.'
# Text chunk/character size: 564
# Block (chunk) id: 40
# File source: 9.txt
# Page number: 1
# Vector distance: 0.3809976875782013
#
# Text: 'VP-Elect Gibran Rakabuming Reacts to Fufufafa Account Polemic\n\nVice President-elect Gibran Rakabuming Raka has found himself in the spotlight after his name was linked to a Kaskus account called Fufufafa. This account has recently sparked widespread discussion on social media, particularly on X, due to its frequent harsh criticisms directed at President-elect Prabowo Subianto and his family.\n\nOn various Kaskus forums and comment sections, the Fufufafa account has repeatedly expressed sharp and sarcastic criticism of Prabowo and his family.'
# Text chunk/character size: 545
# Block (chunk) id: 0
# File source: 1.txt
# Page number: 1
# Vector distance: 0.39270296692848206
#
# Text: "\nGiven Gibran's current role as Vice President-elect alongside Prabowo, the revelation of the account's activities reportedly caused a stir for the palace and Jokowi, as reported by Tempo Magazine's latest edition.\n\nThree officials, two of Jokowi's associates, and three senior figures from the ruling party recounted that the Palace asked the Ministry of Communication and Informatics (Kominfo) to summon the National Cyber and Encryption Agency (BSSN) to verify the account’s authenticity. Another task was to erase traces of Fufufafa’s uploads.\n"
# Text chunk/character size: 548
# Block (chunk) id: 13
# File source: 3.txt
# Page number: 1
# Vector distance: 0.3933064341545105
#
# Text: '\nThe pair were seen welcoming President Joko “Jokowi” Widodo and First Lady Iriana, Gibran’s parents, who arrived in a black presidential car, before they all walked together to enter the venue.\n\nGibran was spotted trailing behind Prabowo, who walked side by side with Jokowi and Vice President Ma’ruf Amin, speaking with the two leaders.\n\nThe event marked the first time Prabowo and Gibran were seen together in public after speculation about their frayed ties emerged, prompted by allegations surrounding an old online account named “Fufufafa”.\n'
# Text chunk/character size: 547
# Block (chunk) id: 7
# File source: 10.txt
# Page number: 1
# Vector distance: 0.40949466824531555
#
# Text: '\nGibran makes first public appearance since online furor over ‘Fufufafa’ account President-elect Prabowo Subianto (left) and vice president-elect Gibran Rakabuming Raka prepare to speak on April 24 during the formal announcement of the winners of the 2024 presidential election at the General Elections Commission (KPU) in Jakarta. (Reuters/Ajeng Dinar Ulfiana)\n'
# Text chunk/character size: 362
# Block (chunk) id: 5
# File source: 10.txt
# Page number: 1
# Vector distance: 0.4166181981563568
#
# Text: '\nOne of the viral posts read: ”Turns out a fired soldier still gets a pension,” which referred to a news story that Prabowo never took his pension money after he left the Army.\n\nSome netizens claimed that they had found a linkage between the Fufufafa account and Gibran, saying the account used the email address of Gibran’s catering firm–Chili Pari–and a phone number connected to digital wallets under the President’s first son.'
# Text chunk/character size: 430
# Block (chunk) id: 33
# File source: 7.txt
# Page number: 1
# Vector distance: 0.4313142001628876
#
# Text: "\nGibran briefly responded to reporters’ inquiries regarding his association with the Kaskus Fufufafa account. When questioned during a visit to Kampung Mutihan in Solo, Central Java, on Tuesday, September 10, Gibran simply directed the media to ask the account owner.\n\nBudi Arie Setiadi, Minister of Communication and Information, also refuted the accusation. “No, it's not (Gibran's). I'll explain it to the DPR (House of Representatives). We'll investigate further, and the truth will undoubtedly be revealed. What's clear is that it doesn't belong to Gibran,” Budi told the media at the Ministry Office in Central Jakarta on Thursday, September 12, 2024.\n\nSimilarly, the Palace denied the allegation that Gibran Rakabuming was behind the Kaskus Fufufafa account."
# Text chunk/character size: 765
# Block (chunk) id: 11
# File source: 2.txt
# Page number: 1
# Vector distance: 0.4317932724952698
#
# Text: "\nDuring the meeting, Prabowo discussed improving relations between the two countries across various sectors, particularly in defense. The Emir of Qatar also expressed his desire for the relationship between the two countries to continue flourishing.\n\nGibran Rakabuming, the eldest son of President Joko Widodo or Jokowi, was confirmed as the vice president-elect at the age of 37. His selection as Prabowo's running mate in the election sparked controversies as it was made feasible by the Constitutional Court’s ruling on the presidential age limit, presided over by Chief Justice Anwar Usman, who is Jokowi’s brother-in-law."
# Text chunk/character size: 626
# Block (chunk) id: 19
# File source: 4.txt
# Page number: 1
# Vector distance: 0.47077658772468567
#
# Text: " She emphasized the need to verify the account's ownership.\n\n“It's not certain yet. I don't know if it belongs to him or not. Make sure of it first,” said Grace at the Presidential Palace complex in Jakarta on Tuesday, September 3, 2024, after a meeting on Govtech with President Jokowi and staffers."
# Text chunk/character size: 300
# Block (chunk) id: 3
# File source: 1.txt
# Page number: 1
# Vector distance: 0.4948948919773102
#
# Text: ' Before and during his time as Mayor of Solo, Tempo had exchanged messages with Gibran via the same phone number.\n\nDuring a visit to Solo, Central Java, on September 10, 2024, Gibran refused to comment on the Fufufafa account controversy. "I don\'t know, ask the account owner. Why ask me?" Several sources close to the Presidential Palace revealed that Gibran had repeatedly denied that the account was his.'
# Text chunk/character size: 407
# Block (chunk) id: 16
# File source: 3.txt
# Page number: 1
# Vector distance: 0.5310319066047668

# %%
# Get the top-N query results only
# Ordered from the lowest vector distance
# Fewer results = faster response
top_n = 5
results_top = sorted(results, key = lambda x: x['distance'], reverse = True)
results_top = results_top[:top_n]

for result in results_top:
    print('Text:', repr(result['text']))
    print('Vector distance:', result['distance'], '\n')
# Out:
# Text: ' Before and during his time as Mayor of Solo, Tempo had exchanged messages with Gibran via the same phone number.\n\nDuring a visit to Solo, Central Java, on September 10, 2024, Gibran refused to comment on the Fufufafa account controversy. "I don\'t know, ask the account owner. Why ask me?" Several sources close to the Presidential Palace revealed that Gibran had repeatedly denied that the account was his.'
# Vector distance: 0.5310319066047668
#
# Text: " She emphasized the need to verify the account's ownership.\n\n“It's not certain yet. I don't know if it belongs to him or not. Make sure of it first,” said Grace at the Presidential Palace complex in Jakarta on Tuesday, September 3, 2024, after a meeting on Govtech with President Jokowi and staffers."
# Vector distance: 0.4948948919773102
#
# Text: "\nDuring the meeting, Prabowo discussed improving relations between the two countries across various sectors, particularly in defense. The Emir of Qatar also expressed his desire for the relationship between the two countries to continue flourishing.\n\nGibran Rakabuming, the eldest son of President Joko Widodo or Jokowi, was confirmed as the vice president-elect at the age of 37. His selection as Prabowo's running mate in the election sparked controversies as it was made feasible by the Constitutional Court’s ruling on the presidential age limit, presided over by Chief Justice Anwar Usman, who is Jokowi’s brother-in-law."
# Vector distance: 0.47077658772468567
#
# Text: "\nGibran briefly responded to reporters’ inquiries regarding his association with the Kaskus Fufufafa account. When questioned during a visit to Kampung Mutihan in Solo, Central Java, on Tuesday, September 10, Gibran simply directed the media to ask the account owner.\n\nBudi Arie Setiadi, Minister of Communication and Information, also refuted the accusation. “No, it's not (Gibran's). I'll explain it to the DPR (House of Representatives). We'll investigate further, and the truth will undoubtedly be revealed. What's clear is that it doesn't belong to Gibran,” Budi told the media at the Ministry Office in Central Jakarta on Thursday, September 12, 2024.\n\nSimilarly, the Palace denied the allegation that Gibran Rakabuming was behind the Kaskus Fufufafa account."
# Vector distance: 0.4317932724952698
#
# Text: '\nOne of the viral posts read: ”Turns out a fired soldier still gets a pension,” which referred to a news story that Prabowo never took his pension money after he left the Army.\n\nSome netizens claimed that they had found a linkage between the Fufufafa account and Gibran, saying the account used the email address of Gibran’s catering firm–Chili Pari–and a phone number connected to digital wallets under the President’s first son.'
# Vector distance: 0.4313142001628876

# %% [markdown]
# ### Misc embedding behind-the-scene
# Simplified process of the `semantic_query` function
#
# For education purpose only, the cell below can be deleted and it won't affect anything

# %%
# query.embedding_model = llmware.models.HFEmbeddingModel
# query.embedding_model.tokenizer = BertTokenizerFast
# query.embedding_model.model = BertModel with BertEmbeddings and BertEncoder

# Bert tokenizer using our embedding model
tokenized_text = query.embedding_model.tokenizer(list(input_query))
# Create embedding vector using 
embedded_vector = query.embedding_model.embedding(input_query)

print(f'Input text (length: {len(input_query)}):', repr(input_query))
print(f'Tokenized text (length: {len(tokenized_text["input_ids"])}):', tokenized_text['input_ids'])
print('Embedded vector shape:', repr(embedded_vector.shape))

EmbeddingChromaDB(lib, query.embedding_model).search_index(
    embedded_vector[0]
)
# Out:
# Input text (length: 8): 'fufufafa'
# Tokenized text (length: 8): [[101, 1042, 102], [101, 1057, 102], [101, 1042, 102], [101, 1057, 102], [101, 1042, 102], [101, 1037, 102], [101, 1042, 102], [101, 1037, 102]]
# Embedded vector shape: (1, 384)
# [({'_id': 2,
#    'block_ID': 1,
#    'doc_ID': 1,
#    'content_type': 'text',
#    'file_type': 'txt',
#    'master_index': 1,
#    'master_index2': 0,
#    'coords_x': 0,
#    'coords_y': 0,
#    'coords_cx': 0,
#    'coords_cy': 0,
#    'author_or_speaker': '',
#    'added_to_collection': '2024-10-14_113114',
#    'file_source': '1.txt',
#    'table': '',
#    'modified_date': '',
#    'created_date': '',
#    'creator_tool': '',
#    'external_files': '',
#    'text': ' The comment history of this account, allegedly belonging to President Joko "Jokowi" Widodo\'s eldest son, dated back to before the 2014 election and extended to 2019 when the rivalry between Prabowo and Jokowi peaked.\n\nAn X user has even compiled a collection of Fufufafa\'s digital footprints. In this thread, the netizen claimed that Gibran allegedly used the usernames Raka Gnarly and Fufufafa on Kaskus.\n\nMany netizens shared several screenshots of uploads made by the Fufufafa account in the thread.',
#    'header_text': '',
#    'text_search': ' The comment history of this account, allegedly belonging to President Joko "Jokowi" Widodo\'s eldest son, dated back to before the 2014 election and extended to 2019 when the rivalry between Prabowo and Jokowi peaked.\n\nAn X user has even compiled a collection of Fufufafa\'s digital footprints. In this thread, the netizen claimed that Gibran allegedly used the usernames Raka Gnarly and Fufufafa on Kaskus.\n\nMany netizens shared several screenshots of uploads made by the Fufufafa account in the thread.',
#    'user_tags': '',
#    'special_field1': '1',
#    'special_field2': '',
#    'special_field3': '',
#    'graph_status': 'false',
#    'dialog': 'false',
#    'embedding_flags': 'embedding_chromadb_mini-lm-sbert'},
#   0.2632857859134674),
#  ({'_id': 16,
#    'block_ID': 15,
#    'doc_ID': 4,
#    'content_type': 'text',
#    'file_type': 'txt',
#    'master_index': 1,
#    'master_index2': 0,
#    'coords_x': 0,
#    'coords_y': 0,
#    'coords_cx': 0,
#    'coords_cy': 0,
#    'author_or_speaker': '',
#    'added_to_collection': '2024-10-14_113114',
#    'file_source': '3.txt',
#    'table': '',
#    'modified_date': '',
#    'created_date': '',
#    'creator_tool': '',
#    'external_files': '',
#    'text': '\nA former government buzzer and two close associates of the Solo family—a reference to Jokowi’s family—who were familiar with the operation of the Fufufafa account, stated that the account was operated by a team working under the account’s owner. The team received content orders from the owner, who sometimes operated the account themselves.\n\nMeanwhile, on social media, netizens presented various pieces of evidence suggesting that the Fufufafa account belonged to Gibran. For example, the phone number registered by the account was suspected Gibran’s.',
#    'header_text': '',
#    'text_search': '\nA former government buzzer and two close associates of the Solo family—a reference to Jokowi’s family—who were familiar with the operation of the Fufufafa account, stated that the account was operated by a team working under the account’s owner. The team received content orders from the owner, who sometimes operated the account themselves.\n\nMeanwhile, on social media, netizens presented various pieces of evidence suggesting that the Fufufafa account belonged to Gibran. For example, the phone number registered by the account was suspected Gibran’s.',
#    'user_tags': '',
#    'special_field1': '15',
#    'special_field2': '',
#    'special_field3': '',
#    'graph_status': 'false',
#    'dialog': 'false',
#    'embedding_flags': 'embedding_chromadb_mini-lm-sbert'},
#   0.30981960892677307),
#  ({'_id': 13,
#    'block_ID': 12,
#    'doc_ID': 4,
#    'content_type': 'text',
#    'file_type': 'txt',
#    'master_index': 1,
#    'master_index2': 0,
#    'coords_x': 0,
#    'coords_y': 0,
#    'coords_cx': 0,
#    'coords_cy': 0,
#    'author_or_speaker': '',
#    'added_to_collection': '2024-10-14_113114',
#    'file_source': '3.txt',
#    'table': '',
#    'modified_date': '',
#    'created_date': '',
#    'creator_tool': '',
#    'external_files': '',
#    'text': "Fufufafa Account Revelation Reportedly Causes Stir for Jokowi, Palace\n\nThe Indonesian social media landscape was recently abuzz with the revelation of a controversial Kaskus account named Fufufafa, which is widely believed to be linked to Gibran Rakabuming Raka, the eldest son of President Joko Jokowi Widodo. The account's existence has ignited a storm of speculation and controversy.\n\nFrom 2014 to 2019, the Fufufafa account posted numerous derogatory statements, often targeting Prabowo Subianto, a political rival of Jokowi during the 2014 and 2019 presidential elections.\n",
#    'header_text': '',
#    'text_search': "Fufufafa Account Revelation Reportedly Causes Stir for Jokowi, Palace\n\nThe Indonesian social media landscape was recently abuzz with the revelation of a controversial Kaskus account named Fufufafa, which is widely believed to be linked to Gibran Rakabuming Raka, the eldest son of President Joko Jokowi Widodo. The account's existence has ignited a storm of speculation and controversy.\n\nFrom 2014 to 2019, the Fufufafa account posted numerous derogatory statements, often targeting Prabowo Subianto, a political rival of Jokowi during the 2014 and 2019 presidential elections.\n",
#    'user_tags': '',
#    'special_field1': '12',
#    'special_field2': '',
#    'special_field3': '',
#    'graph_status': 'false',
#    'dialog': 'false',
#    'embedding_flags': 'embedding_chromadb_mini-lm-sbert'},
#   0.3308858275413513),
#  ({'_id': 38,
#    'block_ID': 37,
#    'doc_ID': 9,
#    'content_type': 'text',
#    'file_type': 'txt',
#    'master_index': 1,
#    'master_index2': 0,
#    'coords_x': 0,
#    'coords_y': 0,
#    'coords_cx': 0,
#    'coords_cy': 0,
#    'author_or_speaker': '',
#    'added_to_collection': '2024-10-14_113114',
#    'file_source': '8.txt',
#    'table': '',
#    'modified_date': '',
#    'created_date': '',
#    'creator_tool': '',
#    'external_files': '',
#    'text': '\nThe account also made homophobic comments about Prabowo’s only son Ragowo “Didit” Hediprasetyo Djojohadikusumo and salacious comments about female celebrities.\n\nAnother post from Fufufafa contained a racist remark toward Novela Nawipa, a cadre of Prabowo’s Gerindra Party from Papua.\n\nNetizens had been speculating that Gibran was behind Fufufafa because posts similar to those made on the forum also appeared on the vice president-elect’s other social media accounts.',
#    'header_text': '',
#    'text_search': '\nThe account also made homophobic comments about Prabowo’s only son Ragowo “Didit” Hediprasetyo Djojohadikusumo and salacious comments about female celebrities.\n\nAnother post from Fufufafa contained a racist remark toward Novela Nawipa, a cadre of Prabowo’s Gerindra Party from Papua.\n\nNetizens had been speculating that Gibran was behind Fufufafa because posts similar to those made on the forum also appeared on the vice president-elect’s other social media accounts.',
#    'user_tags': '',
#    'special_field1': '37',
#    'special_field2': '',
#    'special_field3': '',
#    'graph_status': 'false',
#    'dialog': 'false',
#    'embedding_flags': 'embedding_chromadb_mini-lm-sbert'},
#   0.33779963850975037),
#  ({'_id': 15,
#    'block_ID': 14,
#    'doc_ID': 4,
#    'content_type': 'text',
#    'file_type': 'txt',
#    'master_index': 1,
#    'master_index2': 0,
#    'coords_x': 0,
#    'coords_y': 0,
#    'coords_cx': 0,
#    'coords_cy': 0,
#    'author_or_speaker': '',
#    'added_to_collection': '2024-10-14_113114',
#    'file_source': '3.txt',
#    'table': '',
#    'modified_date': '',
#    'created_date': '',
#    'creator_tool': '',
#    'external_files': '',
#    'text': "\nBesides, the ministry deleted thousands of Fufufafa's posts. Minister of Communication and Informatics Budi Arie Setiadi denied that his ministry was responsible for cleaning up the digital traces of the Fufufafa account. He insisted that the account did not belong to Gibran. However, Budi Arie did not deny that a meeting between Kominfo and BSSN took place.\n\n“We did not specifically discuss Fufufafa,” Budi Arie told Tempo on Friday, October 4, 2024. BSSN Chief Hinsa Siburian and his spokesperson, Ariandi Putra, did not respond to Tempo's messages or calls.\n",
#    'header_text': '',
#    'text_search': "\nBesides, the ministry deleted thousands of Fufufafa's posts. Minister of Communication and Informatics Budi Arie Setiadi denied that his ministry was responsible for cleaning up the digital traces of the Fufufafa account. He insisted that the account did not belong to Gibran. However, Budi Arie did not deny that a meeting between Kominfo and BSSN took place.\n\n“We did not specifically discuss Fufufafa,” Budi Arie told Tempo on Friday, October 4, 2024. BSSN Chief Hinsa Siburian and his spokesperson, Ariandi Putra, did not respond to Tempo's messages or calls.\n",
#    'user_tags': '',
#    'special_field1': '14',
#    'special_field2': '',
#    'special_field3': '',
#    'graph_status': 'false',
#    'dialog': 'false',
#    'embedding_flags': 'embedding_chromadb_mini-lm-sbert'},
#   0.3445359468460083),
#  ({'_id': 33,
#    'block_ID': 32,
#    'doc_ID': 8,
#    'content_type': 'text',
#    'file_type': 'txt',
#    'master_index': 1,
#    'master_index2': 0,
#    'coords_x': 0,
#    'coords_y': 0,
#    'coords_cx': 0,
#    'coords_cy': 0,
#    'author_or_speaker': '',
#    'added_to_collection': '2024-10-14_113114',
#    'file_source': '7.txt',
#    'table': '',
#    'modified_date': '',
#    'created_date': '',
#    'creator_tool': '',
#    'external_files': '',
#    'text': '\nA series of offensive comments posted by the user of an old account named Fufufafa on the internet forum Kaskus, a once-popular online venue for Indonesian youth, has been making the rounds on the internet over the past month, with some of its content involving slanders and mockery about Prabowo.\n\nThe comments were allegedly written between 2014 and 2019, when Prabowo ran twice against Jokowi in two presidential elections marked by sectarian and polarizing presidential campaigns.\n',
#    'header_text': '',
#    'text_search': '\nA series of offensive comments posted by the user of an old account named Fufufafa on the internet forum Kaskus, a once-popular online venue for Indonesian youth, has been making the rounds on the internet over the past month, with some of its content involving slanders and mockery about Prabowo.\n\nThe comments were allegedly written between 2014 and 2019, when Prabowo ran twice against Jokowi in two presidential elections marked by sectarian and polarizing presidential campaigns.\n',
#    'user_tags': '',
#    'special_field1': '32',
#    'special_field2': '',
#    'special_field3': '',
#    'graph_status': 'false',
#    'dialog': 'false',
#    'embedding_flags': 'embedding_chromadb_mini-lm-sbert'},
#   0.3461991250514984),
#  ({'_id': 3,
#    'block_ID': 2,
#    'doc_ID': 1,
#    'content_type': 'text',
#    'file_type': 'txt',
#    'master_index': 1,
#    'master_index2': 0,
#    'coords_x': 0,
#    'coords_y': 0,
#    'coords_cx': 0,
#    'coords_cy': 0,
#    'author_or_speaker': '',
#    'added_to_collection': '2024-10-14_113114',
#    'file_source': '1.txt',
#    'table': '',
#    'modified_date': '',
#    'created_date': '',
#    'creator_tool': '',
#    'external_files': '',
#    'text': " They became increasingly convinced that the account belonged to Gibran following a screenshot of Fufufafa’s comment admitting that he was Jokowi's first son.\n\nGibran's Response to Fufufafa Account \n\nWhen questioned by reporters about the accusation that he owned the Kaskus Fufufafa account, Gibran provided a brief response.\n\n“Ask the account owner,” he said when met after a visit to Mutihan Village, Laweyan District, Solo, Central Java, on Tuesday, September 10, 2024.\n\nMeanwhile, President's Special Staff Grace Natalie stated that the Fufufafa account does not necessarily belong to Gibran.",
#    'header_text': '',
#    'text_search': " They became increasingly convinced that the account belonged to Gibran following a screenshot of Fufufafa’s comment admitting that he was Jokowi's first son.\n\nGibran's Response to Fufufafa Account \n\nWhen questioned by reporters about the accusation that he owned the Kaskus Fufufafa account, Gibran provided a brief response.\n\n“Ask the account owner,” he said when met after a visit to Mutihan Village, Laweyan District, Solo, Central Java, on Tuesday, September 10, 2024.\n\nMeanwhile, President's Special Staff Grace Natalie stated that the Fufufafa account does not necessarily belong to Gibran.",
#    'user_tags': '',
#    'special_field1': '2',
#    'special_field2': '',
#    'special_field3': '',
#    'graph_status': 'false',
#    'dialog': 'false',
#    'embedding_flags': 'embedding_chromadb_mini-lm-sbert'},
#   0.3500187397003174),
#  ({'_id': 37,
#    'block_ID': 36,
#    'doc_ID': 9,
#    'content_type': 'text',
#    'file_type': 'txt',
#    'master_index': 1,
#    'master_index2': 0,
#    'coords_x': 0,
#    'coords_y': 0,
#    'coords_cx': 0,
#    'coords_cy': 0,
#    'author_or_speaker': '',
#    'added_to_collection': '2024-10-14_113114',
#    'file_source': '8.txt',
#    'table': '',
#    'modified_date': '',
#    'created_date': '',
#    'creator_tool': '',
#    'external_files': '',
#    'text': '\nJokowi’s eldest son and vice president-elect Gibran Rakabuming Raka first recently entered the spotlight on social media for allegedly being the owner of “Fufufafa”, an account on Indonesian online forum Kaskus.\n\nThe account posted several times on the forum, including after the 2019 presidential election when it slandered Prabowo Subianto, who eventually became Gibran’s running mate in the February presidential election. In 2019, Prabowo ran for president against Gibran’s father, which resulted in Jokowi’s reelection.\n',
#    'header_text': '',
#    'text_search': '\nJokowi’s eldest son and vice president-elect Gibran Rakabuming Raka first recently entered the spotlight on social media for allegedly being the owner of “Fufufafa”, an account on Indonesian online forum Kaskus.\n\nThe account posted several times on the forum, including after the 2019 presidential election when it slandered Prabowo Subianto, who eventually became Gibran’s running mate in the February presidential election. In 2019, Prabowo ran for president against Gibran’s father, which resulted in Jokowi’s reelection.\n',
#    'user_tags': '',
#    'special_field1': '36',
#    'special_field2': '',
#    'special_field3': '',
#    'graph_status': 'false',
#    'dialog': 'false',
#    'embedding_flags': 'embedding_chromadb_mini-lm-sbert'},
#   0.3726455271244049),
#  ({'_id': 10,
#    'block_ID': 9,
#    'doc_ID': 3,
#    'content_type': 'text',
#    'file_type': 'txt',
#    'master_index': 1,
#    'master_index2': 0,
#    'coords_x': 0,
#    'coords_y': 0,
#    'coords_cx': 0,
#    'coords_cy': 0,
#    'author_or_speaker': '',
#    'added_to_collection': '2024-10-14_113114',
#    'file_source': '2.txt',
#    'table': '',
#    'modified_date': '',
#    'created_date': '',
#    'creator_tool': '',
#    'external_files': '',
#    'text': 'Prabowo Indifferent to Gibran\'s Alleged Fufufafa Account, Says Dasco\n\nThe Daily Chair of the Gerindra Party, Sufmi Dasco Ahmad, has responded to the Kaskus social media account named Fufufafa, which has been accused of frequently attacking the party’s patron chief and President-elect Prabowo Subianto. The account\'s posts, allegedly belonging to President Joko "Jokowi" Widodo\'s eldest son, Gibran Rakabuming, have recently been widely discussed by the public.\n\nDasco clarified that Prabowo has not given much thought to the account\'s uploads.',
#    'header_text': '',
#    'text_search': 'Prabowo Indifferent to Gibran\'s Alleged Fufufafa Account, Says Dasco\n\nThe Daily Chair of the Gerindra Party, Sufmi Dasco Ahmad, has responded to the Kaskus social media account named Fufufafa, which has been accused of frequently attacking the party’s patron chief and President-elect Prabowo Subianto. The account\'s posts, allegedly belonging to President Joko "Jokowi" Widodo\'s eldest son, Gibran Rakabuming, have recently been widely discussed by the public.\n\nDasco clarified that Prabowo has not given much thought to the account\'s uploads.',
#    'user_tags': '',
#    'special_field1': '9',
#    'special_field2': '',
#    'special_field3': '',
#    'graph_status': 'false',
#    'dialog': 'false',
#    'embedding_flags': 'embedding_chromadb_mini-lm-sbert'},
#   0.37407785654067993),
#  ({'_id': 41,
#    'block_ID': 40,
#    'doc_ID': 10,
#    'content_type': 'text',
#    'file_type': 'txt',
#    'master_index': 1,
#    'master_index2': 0,
#    'coords_x': 0,
#    'coords_y': 0,
#    'coords_cx': 0,
#    'coords_cy': 0,
#    'author_or_speaker': '',
#    'added_to_collection': '2024-10-14_113114',
#    'file_source': '9.txt',
#    'table': '',
#    'modified_date': '',
#    'created_date': '',
#    'creator_tool': '',
#    'external_files': '',
#    'text': '\nSufmi’s statement came on the back of protracted speculations of frayed ties between Prabowo and Gibran, the son of outgoing President Joko “Jokowi” Widodo, particularly amid mounting accusations on social media that Gibran was the owner of an old account by the name of “Fufufafa” on the internet forum Kaskus, a once-popular online venue for Indonesian youth.\n\nThe account has in recent weeks been scrutinized by social media users due to several politically incorrect comments that took personal jabs at Prabowo and his family, dating all the way back to 2013.',
#    'header_text': '',
#    'text_search': '\nSufmi’s statement came on the back of protracted speculations of frayed ties between Prabowo and Gibran, the son of outgoing President Joko “Jokowi” Widodo, particularly amid mounting accusations on social media that Gibran was the owner of an old account by the name of “Fufufafa” on the internet forum Kaskus, a once-popular online venue for Indonesian youth.\n\nThe account has in recent weeks been scrutinized by social media users due to several politically incorrect comments that took personal jabs at Prabowo and his family, dating all the way back to 2013.',
#    'user_tags': '',
#    'special_field1': '40',
#    'special_field2': '',
#    'special_field3': '',
#    'graph_status': 'false',
#    'dialog': 'false',
#    'embedding_flags': 'embedding_chromadb_mini-lm-sbert'},
#   0.3809976875782013)]

# %% [markdown]
# ## Prepare model

# %%
# ModelCatalog().list_generative_local_models()

# %%
# Auto-download model first if necessary
# https://huggingface.co/collections/llmware
model_name = 'llmware/bling-tiny-llama-v0'

# Do not load model again if already declared
# Prevent out of memory if the cell is executed multiple times
if 'prompter' not in globals():
    # Temperature 0 = more deterministic, temperature 1 = more creative
    prompter = Prompt().load_model(model_name, temperature = 0.3)

# Forget previous source material (if already added)
# In case we want to ask different topic
prompter.clear_source_materials()

prompter.add_source_query_results(results_top)
responses = prompter.prompt_with_source(
    prompt = input_prompt,
    prompt_name = 'default'
)

responses
# Out:
# [{'llm_response': 'No, Gibran is not behind the Fufufafa account.',
#   'prompt': 'Is Gibran behind fufufafa?',
#   'evidence': ' Before and during his time as Mayor of Solo, Tempo had exchanged messages with Gibran via the same phone number.\n\nDuring a visit to Solo, Central Java, on September 10, 2024, Gibran refused to comment on the Fufufafa account controversy. "I don\'t know, ask the account owner. Why ask me?" Several sources close to the Presidential Palace revealed that Gibran had repeatedly denied that the account was his.\n She emphasized the need to verify the account\'s ownership.\n\n“It\'s not certain yet. I don\'t know if it belongs to him or not. Make sure of it first,” said Grace at the Presidential Palace complex in Jakarta on Tuesday, September 3, 2024, after a meeting on Govtech with President Jokowi and staffers.\n\nDuring the meeting, Prabowo discussed improving relations between the two countries across various sectors, particularly in defense. The Emir of Qatar also expressed his desire for the relationship between the two countries to continue flourishing.\n\nGibran Rakabuming, the eldest son of President Joko Widodo or Jokowi, was confirmed as the vice president-elect at the age of 37. His selection as Prabowo\'s running mate in the election sparked controversies as it was made feasible by the Constitutional Court’s ruling on the presidential age limit, presided over by Chief Justice Anwar Usman, who is Jokowi’s brother-in-law.\n\nGibran briefly responded to reporters’ inquiries regarding his association with the Kaskus Fufufafa account. When questioned during a visit to Kampung Mutihan in Solo, Central Java, on Tuesday, September 10, Gibran simply directed the media to ask the account owner.\n\nBudi Arie Setiadi, Minister of Communication and Information, also refuted the accusation. “No, it\'s not (Gibran\'s). I\'ll explain it to the DPR (House of Representatives). We\'ll investigate further, and the truth will undoubtedly be revealed. What\'s clear is that it doesn\'t belong to Gibran,” Budi told the media at the Ministry Office in Central Jakarta on Thursday, September 12, 2024.\n\nSimilarly, the Palace denied the allegation that Gibran Rakabuming was behind the Kaskus Fufufafa account.\n\nOne of the viral posts read: ”Turns out a fired soldier still gets a pension,” which referred to a news story that Prabowo never took his pension money after he left the Army.\n\nSome netizens claimed that they had found a linkage between the Fufufafa account and Gibran, saying the account used the email address of Gibran’s catering firm–Chili Pari–and a phone number connected to digital wallets under the President’s first son.\n',
#   'instruction': 'default',
#   'model': 'llmware/bling-tiny-llama-v0',
#   'usage': {'input': 689,
#    'output': 16,
#    'total': 705,
#    'metric': 'tokens',
#    'processing_time': 23.14106774330139},
#   'time_stamp': '2024-10-14_113345',
#   'calling_app_ID': '',
#   'rating': '',
#   'account_name': 'llmware',
#   'prompt_id': 'f88003e0-a0fc-4fc3-bee2-a9a0d25ba71d',
#   'batch_id': 0,
#   'evidence_metadata': [{'batch_source_id': 0,
#     'evidence_start_char': 0,
#     'evidence_stop_char': 408,
#     'source_name': '3.txt',
#     'page_num': 1,
#     'doc_id': 1,
#     'block_id': 1},
#    {'batch_source_id': 1,
#     'evidence_start_char': 408,
#     'evidence_stop_char': 709,
#     'source_name': '1.txt',
#     'page_num': 1,
#     'doc_id': 1,
#     'block_id': 1},
#    {'batch_source_id': 2,
#     'evidence_start_char': 709,
#     'evidence_stop_char': 1336,
#     'source_name': '4.txt',
#     'page_num': 1,
#     'doc_id': 1,
#     'block_id': 1},
#    {'batch_source_id': 3,
#     'evidence_start_char': 1336,
#     'evidence_stop_char': 2102,
#     'source_name': '2.txt',
#     'page_num': 1,
#     'doc_id': 1,
#     'block_id': 1},
#    {'batch_source_id': 4,
#     'evidence_start_char': 2102,
#     'evidence_stop_char': 2533,
#     'source_name': '7.txt',
#     'page_num': 1,
#     'doc_id': 1,
#     'block_id': 1}],
#   'biblio': {'3.txt': [1],
#    '1.txt': [1],
#    '4.txt': [1],
#    '2.txt': [1],
#    '7.txt': [1]},
#   'event_type': 'inference',
#   'human_feedback': '',
#   'human_assessed_accuracy': ''}]

# %%
for resp in responses:
    print('Prompt:', repr(resp['prompt']))
    print('Response:', repr(resp['llm_response']))
    print('Evidence/knowledge:', repr(resp['evidence']))
    print('Processing time (seconds):', repr(resp['usage']['processing_time']), '\n')
# Out:
# Prompt: 'Is Gibran behind fufufafa?'
# Response: 'No, Gibran is not behind the Fufufafa account.'
# Evidence/knowledge: ' Before and during his time as Mayor of Solo, Tempo had exchanged messages with Gibran via the same phone number.\n\nDuring a visit to Solo, Central Java, on September 10, 2024, Gibran refused to comment on the Fufufafa account controversy. "I don\'t know, ask the account owner. Why ask me?" Several sources close to the Presidential Palace revealed that Gibran had repeatedly denied that the account was his.\n She emphasized the need to verify the account\'s ownership.\n\n“It\'s not certain yet. I don\'t know if it belongs to him or not. Make sure of it first,” said Grace at the Presidential Palace complex in Jakarta on Tuesday, September 3, 2024, after a meeting on Govtech with President Jokowi and staffers.\n\nDuring the meeting, Prabowo discussed improving relations between the two countries across various sectors, particularly in defense. The Emir of Qatar also expressed his desire for the relationship between the two countries to continue flourishing.\n\nGibran Rakabuming, the eldest son of President Joko Widodo or Jokowi, was confirmed as the vice president-elect at the age of 37. His selection as Prabowo\'s running mate in the election sparked controversies as it was made feasible by the Constitutional Court’s ruling on the presidential age limit, presided over by Chief Justice Anwar Usman, who is Jokowi’s brother-in-law.\n\nGibran briefly responded to reporters’ inquiries regarding his association with the Kaskus Fufufafa account. When questioned during a visit to Kampung Mutihan in Solo, Central Java, on Tuesday, September 10, Gibran simply directed the media to ask the account owner.\n\nBudi Arie Setiadi, Minister of Communication and Information, also refuted the accusation. “No, it\'s not (Gibran\'s). I\'ll explain it to the DPR (House of Representatives). We\'ll investigate further, and the truth will undoubtedly be revealed. What\'s clear is that it doesn\'t belong to Gibran,” Budi told the media at the Ministry Office in Central Jakarta on Thursday, September 12, 2024.\n\nSimilarly, the Palace denied the allegation that Gibran Rakabuming was behind the Kaskus Fufufafa account.\n\nOne of the viral posts read: ”Turns out a fired soldier still gets a pension,” which referred to a news story that Prabowo never took his pension money after he left the Army.\n\nSome netizens claimed that they had found a linkage between the Fufufafa account and Gibran, saying the account used the email address of Gibran’s catering firm–Chili Pari–and a phone number connected to digital wallets under the President’s first son.\n'
# Processing time (seconds): 23.14106774330139

# %% [markdown]
# ## TODO
#
# References:
#
# - https://github.com/llmware-ai/llmware/tree/main/examples/Embedding (Migrate database)
# - https://github.com/llmware-ai/llmware/tree/main/examples/Use_Cases (REST API)
# - https://github.com/llmware-ai/llmware/tree/main/examples/UI (Streamlit UI)
